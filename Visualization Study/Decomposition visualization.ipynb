# %% [markdown]
# ## Iris 2D or 3D visualization

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris, fetch_olivetti_faces
from sklearn.decomposition import PCA, IncrementalPCA, KernelPCA, SparsePCA
from sklearn.decomposition import TruncatedSVD, DictionaryLearning, FactorAnalysis
from sklearn.decomposition import FastICA, NMF, LatentDirichletAllocation
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from mpl_toolkits.mplot3d import axes3d, Axes3D
from mpl_toolkits import mplot3d

# %%
iris, labels = load_iris(return_X_y=True)

# %%
def plot_iris(iris, labels):
    plt.figure()
    colors = ['navy','purple','red']
    for xy, label in zip(iris, labels):
        plt.scatter(xy[0],xy[1],color=colors[label])

# %% [markdown]
# ### Original

# %% [markdown]
# ### Original 2D

# %%
plot_iris(iris, labels)

# %% [markdown]
# ### Original 3D

# %%
xs=iris[:,0]
ys=iris[:,1]
zs=iris[:,2]

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(xs,ys,zs, c=labels, cmap='winter' ,marker='^')

ax.set_xlabel('x', fontsize=25)
ax.set_ylabel('y', fontsize=25)
ax.set_zlabel('z', fontsize=25)
# ax.view_init(50,10)
plt.show()

# %% [markdown]
# ### PCA

# %%
model = PCA(n_components=3, random_state=0)
model.fit(iris)
transformed_iris = model.transform(iris)
transformed_iris.shape
# Out:
# (150, 3)

# %% [markdown]
# ### PCA 2D

# %%
plot_iris(transformed_iris, labels)

# %% [markdown]
# ### PCA 3D

# %%
xs=transformed_iris[:,0]
ys=transformed_iris[:,1]
zs=transformed_iris[:,2]

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(xs,ys,zs, c=labels, cmap='winter' ,marker='^')

ax.set_xlabel('x', fontsize=25)
ax.set_ylabel('y', fontsize=25)
ax.set_zlabel('z', fontsize=25)
ax.view_init(50,10)
plt.show()

# %% [markdown]
# ### Kernel PCA

# %%
model = KernelPCA(n_components=3, kernel='rbf', random_state=0)
model.fit(iris)
transformed_iris = model.transform(iris)
transformed_iris.shape
# Out:
# (150, 3)

# %% [markdown]
# ### Kernel PCA 2D

# %%
plot_iris(transformed_iris, labels)

# %% [markdown]
# ### Kernel PCA 3D

# %%
xs=transformed_iris[:,0]
ys=transformed_iris[:,1]
zs=transformed_iris[:,2]

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(xs,ys,zs, c=labels, cmap='winter' ,marker='^')

ax.set_xlabel('x', fontsize=25)
ax.set_ylabel('y', fontsize=25)
ax.set_zlabel('z', fontsize=25)
ax.view_init(70,10)
plt.show()

# %% [markdown]
# ### Factor Analysis

# %%
model = FactorAnalysis(n_components=3, random_state=0)
model.fit(iris)
transformed_iris = model.transform(iris)
transformed_iris.shape
# Out:
# (150, 3)

# %% [markdown]
# ### Factor Analysis 2D

# %%
plot_iris(transformed_iris, labels)

# %% [markdown]
# ### Factor Analysis 3D

# %%
xs=transformed_iris[:,0]
ys=transformed_iris[:,1]
zs=transformed_iris[:,2]

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(xs,ys,zs, c=labels, cmap='winter' ,marker='^')

ax.set_xlabel('x', fontsize=25)
ax.set_ylabel('y', fontsize=25)
ax.set_zlabel('z', fontsize=25)
# ax.view_init(70,10)
plt.show()

# %% [markdown]
# ### NMF

# %%
model = NMF(n_components=3, random_state=0)
model.fit(iris)
transformed_iris = model.transform(iris)
transformed_iris.shape
# Out:
# (150, 3)

# %% [markdown]
# ### NMF 2D

# %%
plot_iris(transformed_iris, labels)

# %% [markdown]
# ### NMF 3D

# %%
xs=transformed_iris[:,0]
ys=transformed_iris[:,1]
zs=transformed_iris[:,2]

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(xs,ys,zs, c=labels, cmap='winter' ,marker='^')

ax.set_xlabel('x', fontsize=25)
ax.set_ylabel('y', fontsize=25)
ax.set_zlabel('z', fontsize=25)
ax.view_init(70,10)
plt.show()

# %% [markdown]
# ### LDA

# %%
model = LatentDirichletAllocation(n_components=3, random_state=0)
model.fit(iris)
transformed_iris = model.transform(iris)
transformed_iris.shape
# Out:
# (150, 3)

# %% [markdown]
# ### LDA 2D

# %%
plot_iris(transformed_iris, labels)

# %% [markdown]
# ### LDA 3D

# %%
xs=transformed_iris[:,0]
ys=transformed_iris[:,1]
zs=transformed_iris[:,2]

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(xs,ys,zs, c=labels, cmap='winter' ,marker='^')

ax.set_xlabel('x', fontsize=25)
ax.set_ylabel('y', fontsize=25)
ax.set_zlabel('z', fontsize=25)
ax.view_init(10,50)
plt.show()

# %% [markdown]
# + what is the best?
