# %% [markdown]
# # BeautifulSoup naver News

# %%
from bs4 import BeautifulSoup
import urllib.request
from urllib.parse import quote
import pandas as pd
import requests

# %% [markdown]
# ### 1. 검색어에 따른 뉴스 정보 추출

# %%
url_query = quote(str(input('검색어 :')))
url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+url_query

j = int(input('원하는 검색 페이지수 :'))
print()

df_title_list = []
df_company_list = []
df_url_list = []

for i in range(j):
    
    search_url = urllib.request.urlopen(url).read()
    soup = BeautifulSoup(search_url, 'html.parser')

    check = soup.find_all('div', {'class':'news_area'})

    for i in range(len(check)):
        a = check[i].find('a',{'class':'news_tit'})['title']
        b = check[i].find('a',{'class':'info press'}).text
        c = check[i].find('a',{'class':'news_tit'})['href']
#         print('news_title = ', a)
#         print('news_compant = ', b)
#         print('news_url = ', c)
        
        df_title_list.append(a)
        df_company_list.append(b)
        df_url_list.append(c)
        
    try:
        ab = soup.find('a',{'class':'btn_next'}).get('href')
        url = 'https://search.naver.com/search.naver' + ab
    except:
        break
    
#     print()
    
news_df_frame = pd.DataFrame([df_company_list, df_title_list, df_url_list],index=['company', 'title', 'url'])
news_df_frame = news_df_frame.T

news_df_frame
# Out:
# 검색어 :무인자동차
# 원하는 검색 페이지수 :3
#          company                                              title  \
# 0           영남일보                              [혁신 산업 투어] 하늘로 가는 자동차
# 1         이뉴스투데이                      과천시 별양동 주민센터, 무인민원발급기 24시간 운영
# 2           로봇신문         美 와이보틱, 클리어패스와 UGV(무인지상차량)용 만능 무선충전기 공급 제휴
# 3           산업일보     VisionNav, Korea MAT에서 최신 무인 산업용 자동차 및 솔루션 선보여
# 4    KOTRA해외시장뉴스                 레벨 3 자율주행 시작으로 본 일본 자율주행 자동차 산업 현황
# 5           중부일보  "이용자 편의 위해"…과천시 별양동 주민센터, 무인민원발급기 24시간 운영 4곳으로 확대
# 6           이데일리                       대양전기공업, 자동차용 센서로 기업가치 재평가-하이
# 7            KBS                  [지구촌 IN] 슈퍼마켓·레스토랑도 ‘무인화’ 바람…반응은?
# 8        인더스트리뉴스                     조선·자동차 등 주력 산업 디지털전환 R&D 사업 착수
# 9         엑스포츠뉴스       '무인식당 行' 허재, 옛날 사람 인증…생애 첫 비대면 주문에 진땀 (당나귀귀)
# 10          뉴데일리                 세종시, 하반기 노란신호등·무인교통단속 장비 설치…30억 투입
# 11          로봇신문               中 포니닷에이아이, 美 캘리포니아서 '무인' 자율차 시범운행 허가
# 12        녹색경제신문  [산업 이모저모] LG전자, 국내 가전업계 최초 '무인' 매장 운영…비대면 열풍에 ...
# 13    한국일보언론사 선정            '송골매'보다 똑똑한 정찰기 나오나… 軍 '무인기 자율항법' 기술 개발
# 14     뉴시스언론사 선정                 모셔널, 무인 자율주행차 기술력 입증…일반도로 시험 주행 성공
# 15          전자신문                   광주시, '무인 자율주행기술 언택트 서비스 실증사업' 선정
# 16   KOTRA해외시장뉴스                                       독일 자동차 산업 정보
# 17          노컷뉴스                   광주시, 무인 자율주행 언택트 서비스 실증 사업 공모 선정
# 18     머니S언론사 선정                      “영화 속 장면이 현실로” 무인 모빌리티 시대 열린다
# 19    한국경제언론사 선정              현대차 자율주행 합작사 '모셔널', 일반도로 무인 자율주행 '성공'
# 20        내외경제tv         [UP! START] "부처 핸썸" 파킹클라우드, AI 무인주차장 구축 가속
# 21         머니투데이                   넷마블 사옥에 AI 무인주차장 구축…무정차 통과로 요금결제
# 22    서울경제언론사 선정                  美 일반도로서 무인주행 성공···자율차도 치고 나가는 현대차
# 23  파이낸셜뉴스언론사 선정                          현대로템, 기동전투체계 원격 무인화 과제 수주
# 24           뉴시스                                 전기 자동차 무인충전 로봇 시스템
# 25          국방일보  4차 산업혁명 시대 ‘고성능·친환경·PAV(Personal Air Vehicle:하...
# 26  파이낸셜뉴스언론사 선정                        판교테크노밸리 '자율주행자동차 시범운행지구 지정'
# 27          로봇신문                 [KRoC 2021] "현대자동차, 로봇기술의 내재화에 집중"
# 28           더팩트                아산시, 무인 민원발급기 24시간 운영... 시청 별관 등 6대
# 29          국제뉴스                            인천시교육청, 청사 내 무인민원발급기 설치
#
#                                                   url
# 0   https://www.yeongnam.com/web/view.php?key=2021...
# 1   http://www.enewstoday.co.kr/news/articleView.h...
# 2   http://www.irobotnews.com/news/articleView.htm...
# 3                   http://www.kidd.co.kr/news/222426
# 4   http://news.kotra.or.kr/user/extra/kotranews/b...
# 5   http://www.joongboo.com/news/articleView.html?...
# 6   http://www.edaily.co.kr/news/newspath.asp?news...
# 7   https://news.kbs.co.kr/news/view.do?ncd=519331...
# 8   http://www.industrynews.co.kr/news/articleView...
# 9   https://www.xportsnews.com/?ac=article_view&en...
# 10  http://cc.newdaily.co.kr/site/data/html/2021/0...
# 11  http://www.irobotnews.com/news/articleView.htm...
# 12  http://www.greened.kr/news/articleView.html?id...
# 13  https://hankookilbo.com/News/Read/A20210511145...
# 14  http://www.newsis.com/view/?id=NISX20210223_00...
# 15               http://www.etnews.com/20210517000053
# 16  http://news.kotra.or.kr/user/extra/kotranews/b...
# 17           https://www.nocutnews.co.kr/news/5553490
# 18  http://moneys.mt.co.kr/news/mwView.php?no=2021...
# 19  https://www.hankyung.com/economy/article/20210...
# 20  http://www.nbntv.co.kr/news/articleView.html?i...
# 21  http://news.mt.co.kr/mtview.php?no=20210513103...
# 22        https://www.sedaily.com/NewsView/22IN737UWH
# 23      http://www.fnnews.com/news/202012310839206373
# 24  http://www.newsis.com/view/?id=NISI20210407_00...
# 25  http://kookbang.dema.mil.kr/newsWeb/20210525/1...
# 26      http://www.fnnews.com/news/202104261101560318
# 27  http://www.irobotnews.com/news/articleView.htm...
# 28     http://news.tf.co.kr/read/national/1860147.htm
# 29  http://www.gukjenews.com/news/articleView.html...

# %% [markdown]
# ---

# %% [markdown]
# ### 2. 검색어에 따른 뉴스 정보 추출 + 네이버 뉴스 기사 본문 내용 추출

# %%
url_query = quote(str(input('검색어 : ')))
url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+url_query

j = int(input('원하는 검색 페이지수 : '))
print()

df_title_list = []
df_company_list = []
df_url_list = []

for i in range(j):
    
    search_url = urllib.request.urlopen(url).read()
    soup = BeautifulSoup(search_url, 'html.parser')

    check = soup.find_all('div', {'class':'news_area'})

    for i in range(len(check)):
        a = check[i].find('a',{'class':'news_tit'})['title']
        b = check[i].find('a',{'class':'info press'}).text
        c = check[i].find('a',{'class':'news_tit'})['href']
#         print('news_title = ', a)
#         print('news_compant = ', b)
#         print('news_url = ', c)
        
        df_title_list.append(a)
        df_company_list.append(b)
        df_url_list.append(c)
        

# ///////////////////////////////////////////////////////////////
# 뉴스 본문 내용 추출      
    
    naver_news = soup.select('div.news_info > div')
    
    for i in naver_news:

        naver_news_url = i.select_one('a:nth-of-type(2)')

        if naver_news_url == None:
            continue
            
        else:
            url = naver_news_url['href']
            
            headers = ***** #insert your user agent
            try:
                search_url = requests.get(url, headers = headers)
                soup = BeautifulSoup(search_url.text, 'html.parser')

                title = soup.find('h3',{'id':'articleTitle'}).text
                time = soup.find('span',{'class':'t11'}).text
                news_content = soup.find('div',{'id':'articleBodyContents'}).text

                news_content = news_content.replace('\n','')
                news_content = news_content.replace('\t','')
                news_content = news_content.replace('// flash 오류를 우회하기 위한 함수 추가function _flash_removeCallback() {}','')

                print(title)
                print(time)
                print(news_content)
                print()
            except:
                continue
        
# ///////////////////////////////////////////////////////////////
        
    try:
        ab = soup.find('a',{'class':'btn_next'}).get('href')
        url = 'https://search.naver.com/search.naver' + ab
    except:
        break
    
    print()
    
news_df_frame = pd.DataFrame([df_company_list, df_title_list, df_url_list],index=['company', 'title', 'url'])
news_df_frame = news_df_frame.T

news_df_frame
# Out:
# 검색어 : 무인주차장
# 원하는 검색 페이지수 : 3
#
# 시흥시, 9월부터 갯골생태공원 주차장 유료 전환
# 2021.05.25. 오전 9:51
# 방문 차량 증가로 도로 정체 등 문제유료화 통해 차량 통제·주차정보 제공사업비 4억원 투입…7~8월 시범운영[시흥=이데일리 이종일 기자] 경기 시흥시는 9월부터 갯골생태공원 주차장을 유료로 운영한다고 25일 밝혔다.갯골생태공원 주차장은 현재 시민 편의를 위해 무료로 운영한다. 그러나 공원이 관광명소로 자리 잡으며 방문차량이 지속적으로 증가해 도로 정체, 주차공간 부족 등의 불편이 커졌다.  이에 시는 4억원을 투입해 공원 주차장 유료화 사업을 하기로 결정했다. 주차 차단기, 무인요금정산기, 주차장 CCTV를 설치하고 마유로와 진입도로에 전광판 3개를 달아 공원 진입 전 주차장 상황을 방문객에게 안내할 계획이다. 시는 다음 달까지 시설 공사를 마치고 7~8월 시범운영을 거쳐 9월부터 유료주차장을 운영한다. 주차요금은 행정예고와 의견수렴을 거쳐 시 홈페이지에 고시할 예정이다.시 관계자는 “낮은 회전율과 장기주차 개선을 위해 주차장을 유료화하고 부족한 주차장 추가 확보사업을 진행하고 있다”며 “시민, 관광객들이 갯골생태공원을 편리하게 이용할 수 있게 최선을 다하겠다”고 말했다.시흥시청 전경.이종일 (apple223@edaily.co.kr)▶ #24시간 빠른 #미리보는 뉴스 #eNews+▶ 네이버에서 '이데일리 뉴스'를 만나보세요▶ 빡침해소, 청춘뉘우스 '스냅타임'＜ⓒ종합 경제정보 미디어 이데일리 - 무단전재 & 재배포 금지＞
#
# 넷마블 사옥에 AI 무인주차장 구축…무정차 통과로 요금결제
# 2021.05.13. 오전 10:59
# [머니투데이 최태범 기자] 주차 플랫폼 '아이파킹'을 운영하는 파킹클라우드가 서울 구로디지털단지에 위치한 넷마블 신사옥 'G타워(지타워)'에 인공지능(AI) 무인주차관제시스템을 구축했다고 13일 밝혔다. G타워는 지상 41층, 지하 5층, 연면적 18만㎡로 약 7000명이 입주 가능한 대형 빌딩이다. 이번에 구축한 아이파킹 주차장은 지하 5개층에 1368대를 주차할 수 있는 규모다. 파킹클라우드는 현재 NHN한국사이버결제, 롯데IT캐슬, 한화비즈메트로 등 IT 기업 건물부터 현대아울렛, 마리오아울렛 등 쇼핑몰까지 G밸리(구로·가산디지털단지) 내 100여곳에 아이파킹존을 구축했다. 파킹클라우드 관계자는 "이번 수주로 구로와 가산디지털단지를 아우르는 G밸리에서 AI 무인주차장 점유 1위를 확고하게 굳힐 것으로 기대한다"고 했다. 파킹클라우드는 G타워에 하이패스처럼 무정차 통과로 주차요금이 자동결제되는 '아이파킹 파킹패스'를 도입했다. 주차장 출입구 AI 카메라가 차량번호 인식 후 클라우드에 등록된 차량정보와 카드를 매칭하는 영상인식 결제 서비스다. 아이파킹 파킹패스는 2018년 아마존이 선보인 무인상점 '아마존 고'의 저스트 워크 아웃(Just Walk Out)' 보다 3년 이상 앞서 상용화한 '저스트 드라이브 아웃(Just Drive Out technology)' 기술이다. 국내 드라이브 스루 방식에서 큰 비중을 차지한다.파킹클라우드는 2015년 국내 최초로 AI 무인주차관제시스템을 선보인 이후 매달 100곳 이상 아이파킹존을 확장하고 있다. 롯데월드타워와 해운대 엘시티 등 초고층 빌딩과 이마트, KT, 교보타워, 여의도 IFC, 영등포 타임스퀘어 등 전국 랜드마크 3900여곳의 아이파킹존에서 하루 100만대의 차량이 이용한다. 지난해부터는 주차 공간에 ICT 기술을 고도화 시킨 성과를 인정받아 주차기업 중 유일하게 현대자동차그룹과 파트너십을 체결하고 차량 내부 간편결제 시스템 '카페이'에 탑재되는 주차장 정보·결제 서비스를 지원하고 있다. 최태범 기자 bum_t@mt.co.kr▶부동산 투자는 [부릿지]▶주식 투자는 [부꾸미TALK]▶부자되는 뉴스, 머니투데이 구독하기 <저작권자 ⓒ '돈이 보이는 리얼타임 뉴스' 머니투데이, 무단전재 및 재배포 금지>
#
# 부산 남구, 용호골목시장 공영주차장 준공
# 2021.05.21. 오전 11:24
# 총 사업비 24억원 투입, 24면 공영주차장 조성전통시장 이용객 주차불편 해소와 지역경제 활성화 기여부산 남구(구청장 박재범)가 전통시장의 경쟁력 확보와 이용객 주차불편 해소를 위해 발 벗고 나섰다. 남구는 용호골목시장에 24면 규모의 공영주차장을 조성했다고 20일 밝혔다.용호골목시장은 1975년 개설되어 농·수산물, 정육, 잡화, 식료품 등 108개 점포로 이루어진 남구 용호동의 대표적인 전통시장이다. 많은 이용객이 있음에도 불구하고 그간 주차시설 부재가 시장의 가장 큰 불편사항으로 지적되었다. 남구는 불편해소를 위해 지난 2019년 7월 중소벤처기업부 주관한 전통시장 및 상점가 활성화 지원사업 공모에 신청하였고, 그 해 12월 최종 선정되어 총사업비 24억 원을 투입하여 공영주차장을 조성하게 되었다.또한, 남구는 주차장의 효율적인 관리를 위해 무인관제시스템을 도입하고, 주차장 운영방법은 공개입찰을 통해 사업자를 선정하여 6월 본격 운영을 앞두고 있다.박재범 남구청장은 “용호골목시장은 남구의 가장 대표적인 전통시장으로 주차장 조성으로 주차불편이 크게 해소돼 시장을 찾는 이용객이 많이 늘어날 것으로 기대된다. 코로나19 장기화와 비대면 온라인 소비변화로 어려움을 겪고 있는 영세상인들에게 힘이 되고, 지역경제도 활력을 찾을 수 있는 실효적인 정책을 더욱 발굴해 나가겠다.”고 밝혔다.이상윤 기자 nurumi@busan.com▶ 네이버에서 부산일보 구독하기 클릭!▶ 부산닷컴 회원가입. 회원 전환하면 부산일보 지면보기 무료이벤트▶ 부산일보 홈 바로가기
#   company                                              title  \
# 0    이데일리                         시흥시, 9월부터 갯골생태공원 주차장 유료 전환
# 1  이뉴스투데이               셀프스토리지 개인 창고, 무인화로 편리하게 이용 가능한 큐스토리지
# 2    이투뉴스                        안심페이 골프장 전용 무인결제시스템 키오스크 출시
# 3   머니투데이                   넷마블 사옥에 AI 무인주차장 구축…무정차 통과로 요금결제
# 4  내외경제tv         [UP! START] "부처 핸썸" 파킹클라우드, AI 무인주차장 구축 가속
# 5    부산일보                             부산 남구, 용호골목시장 공영주차장 준공
# 6   부산MBC                             용호골목시장 공영주차장 준공..6월 운영
# 7    내일신문                                 할머니·할아버지도 무인주문 손쉽게
# 8    국제신문                부산 북구빙상센터 방치된 주차장…市, 무인시스템으로 정상화시킨다
# 9   에이빙뉴스  [2021 대한민국 전기산업엑스포 현장인터뷰] 모던텍, 무인로봇충전기로 자율주행차 ...
#
#                                                  url
# 0  http://www.edaily.co.kr/news/newspath.asp?news...
# 1  http://www.enewstoday.co.kr/news/articleView.h...
# 2  http://www.e2news.com/news/articleView.html?id...
# 3  http://news.mt.co.kr/mtview.php?no=20210513103...
# 4  http://www.nbntv.co.kr/news/articleView.html?i...
# 5  http://www.busan.com/view/busan/view.php?code=...
# 6        https://busanmbc.co.kr/article/ekgcus8IR8l6
# 7      http://www.naeil.com/news_view/?id_art=386449
# 8  http://www.kookje.co.kr/news2011/asp/newsbody....
# 9  http://kr.aving.net/news/view.php?articleId=16...

# %% [markdown]
# ---

# %% [markdown]
# ### 3. 단일 네이버 뉴스 추출

# %%
url = 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=421&aid=0005182421'
headers = ***** #insert your user agent

try:
    search_url = requests.get(url, headers=headers)
except:
    print('g')
    

search_url = requests.get(url, headers = headers)
soup = BeautifulSoup(search_url.text, 'html.parser')

title = soup.find('h3',{'id':'articleTitle'}).text
time = soup.find('span',{'class':'t11'}).text
news_content = soup.find('div',{'id':'articleBodyContents'}).text

news_content = news_content.replace('\n','')
news_content = news_content.replace('\t','')
news_content = news_content.replace('// flash 오류를 우회하기 위한 함수 추가function _flash_removeCallback() {}','')

news_content
# Out:
# '전북 부안군이 조성한 부안 마실공영주차장이 3월1일부터 전면 유료화로 운영된다. © 뉴스1(부안=뉴스1) 박제철 기자 = 전북 부안군이 조성한 부안 마실공영주차장이 3월1일부터 전면 유료화로 운영된다.마실공영주차장은 부안상설시장 및 인근 상가를 이용하는 군민과 관광객의 주차불편을 해소하고 불법 주정차를 방지하기 위해 옛 농업은행 부안군지부 부지에 조성됐다.  총사업비 44억원을 들여 주차장면적 2469㎡, 지상 2층 규모로 주차면수 99면을 설치했다.     24시간 무인으로 운영되며 주차가능차량은 주차장 높이를 고려해 승용차와 승합차(12인승 이하), 1톤 화물차(2.1m 이하)로 제한된다.    주차요금은 최초 주차부터 2시간까지 무료이며 2시간 이후부터는 기본요금 2000원에 20분당 1000원을 징수하고 1일 최대 3만원을 징수한다.    군 관계자는 “최초 2시간까지 무료 주차를 할 수 있어 부안상설시장 및 인근 상가를 이용하는 고객들에게 큰 도움이 될 것으로 기대된다”며 “다만 장시간 주차를 하는 경우 주차요금이 발생하므로 인근 무료 주차장을 이용해 달라”고 당부했다.jcpark@news1.kr▶ 네이버 메인에서 [뉴스1] 구독하기!▶  뉴스1&BBC; 한글 뉴스 ▶  터닝포인트 2021 © 뉴스1코리아(news1.kr), 무단 전재 및 재배포 금지'
